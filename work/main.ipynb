# %%
print("hello world")
# Out:
# hello world

# %%
import time, string
from concurrent.futures import ProcessPoolExecutor
from concurrent.futures import ThreadPoolExecutor
import function as f

# %%
#全て素数であることがわかっている数リスト(調べた)
NUMBER1 = [9007199254740881,7365373222715531,583964556541679,92709568269121,112272535095293]
#全て素数でないことがわかっている数リスト(１の位が偶数だから)
NUMBER2 = [4567876543234562,13456767689342,2345689302394586794,12039485780398342,12304596875940348578]
#上二つの混合リスト
NUMBER3 = [12039485780398342,9007199254740881,4567876543234562,7365373222715531,13456767689342,583964556541679,2345689302394586794,92709568269121,112272535095293,12304596875940348578]

# %%
def func_1(numbers):
    start = time.time() ## 処理開始時間
    ##============計算処理==============
    for number, result in zip(numbers, map(f.is_prime, numbers)):
        print(f"{number} は素数ですか？: {result}")
    ##=================================
    end = time.time()  ## 処理終了時間
    print(f"実行時間:{end - start}")
    print("==============================")

# %%
print("シングルプロセスでの素数判断処理")
func_1(NUMBER1)
func_1(NUMBER2)
func_1(NUMBER3)
# Out:
# シングルプロセスでの素数判断処理
# 9007199254740881 は素数ですか？: True
# 7365373222715531 は素数ですか？: True
# 583964556541679 は素数ですか？: True
# 92709568269121 は素数ですか？: True
# 112272535095293 は素数ですか？: True
# 実行時間:24.371237993240356
# ==============================
# 4567876543234562 は素数ですか？: False
# 13456767689342 は素数ですか？: False
# 2345689302394586794 は素数ですか？: False
# 12039485780398342 は素数ですか？: False
# 12304596875940348578 は素数ですか？: False
# 実行時間:0.0011036396026611328
# ==============================
# 12039485780398342 は素数ですか？: False
# 9007199254740881 は素数ですか？: True
# 4567876543234562 は素数ですか？: False
# 7365373222715531 は素数ですか？: True
# 13456767689342 は素数ですか？: False
# 583964556541679 は素数ですか？: True
# 2345689302394586794 は素数ですか？: False
# 92709568269121 は素数ですか？: True
# 112272535095293 は素数ですか？: True
# 12304596875940348578 は素数ですか？: False
# 実行時間:22.427025079727173
# ==============================

# %%
def func_2(numbers):
    start = time.time() ## 処理開始時間
    ##============計算処理==============
    with ProcessPoolExecutor(max_workers=3) as e:
        for number, result in zip(numbers, e.map(f.is_prime, numbers)):
            print(f"{number} は素数ですか？: {result}")
    ##=================================
    end = time.time()  ## 処理終了時間
    print(f"実行時間:{end - start}")
    print("==============================")

# %%
print("マルチプロセスでの素数判断処理")
func_2(NUMBER1)
func_2(NUMBER2)
func_2(NUMBER3)
# Out:
# マルチプロセスでの素数判断処理
# 9007199254740881 は素数ですか？: True
# 7365373222715531 は素数ですか？: True
# 583964556541679 は素数ですか？: True
# 92709568269121 は素数ですか？: True
# 112272535095293 は素数ですか？: True
# 実行時間:10.575605630874634
# ==============================
# 4567876543234562 は素数ですか？: False
# 13456767689342 は素数ですか？: False
# 2345689302394586794 は素数ですか？: False
# 12039485780398342 は素数ですか？: False
# 12304596875940348578 は素数ですか？: False
# 実行時間:0.05588412284851074
# ==============================
# 12039485780398342 は素数ですか？: False
# 9007199254740881 は素数ですか？: True
# 4567876543234562 は素数ですか？: False
# 7365373222715531 は素数ですか？: True
# 13456767689342 は素数ですか？: False
# 583964556541679 は素数ですか？: True
# 2345689302394586794 は素数ですか？: False
# 92709568269121 は素数ですか？: True
# 112272535095293 は素数ですか？: True
# 12304596875940348578 は素数ですか？: False
# 実行時間:14.901196002960205
# ==============================

# %%
print("シングルスレッドでの総和計算")

start = time.time() ## 処理開始時間
##============計算処理==============
number = 20
ret = map(f.my_sum, range(1, number + 1))
result = [r for r in ret]
print(f"{number}までの総和: {result}")
##=================================
end = time.time()  ## 処理終了時間
print(f"実行時間:{end - start}")
# Out:
# シングルスレッドでの総和計算
# 20までの総和: [1, 3, 6, 10, 15, 21, 28, 36, 45, 55, 66, 78, 91, 105, 120, 136, 153, 171, 190, 210]
# 実行時間:21.73795199394226

# %%
print("マルチスレッドでの総和計算")

for i in [2,4,8,12,16,24,36,48,96]:
    print(f"スレッド数{i}で処理しています...")
        
    start = time.time() ## 処理開始時間
    ##============計算処理==============
    number = 20
    with ThreadPoolExecutor(max_workers=i) as e:
        ret = e.map(f.my_sum, range(1, number + 1))
    result = [r for r in ret]
    print(f"{number}までの総和: {result}")
    ##=================================
    end = time.time()  ## 処理終了時間
    print(f"実行時間:{end - start}")
    print("==============================")
# Out:
# マルチスレッドでの総和計算
# スレッド数2で処理しています...
# 20までの総和: [1, 3, 6, 10, 15, 21, 28, 36, 45, 55, 66, 78, 91, 105, 120, 136, 153, 171, 190, 210]
# 実行時間:11.719307661056519
# ==============================
# スレッド数4で処理しています...
# 20までの総和: [1, 3, 6, 10, 15, 21, 28, 36, 45, 55, 66, 78, 91, 105, 120, 136, 153, 171, 190, 210]
# 実行時間:6.131019353866577
# ==============================
# スレッド数8で処理しています...
# 20までの総和: [1, 3, 6, 10, 15, 21, 28, 36, 45, 55, 66, 78, 91, 105, 120, 136, 153, 171, 190, 210]
# 実行時間:3.700978994369507
# ==============================
# スレッド数12で処理しています...
# 20までの総和: [1, 3, 6, 10, 15, 21, 28, 36, 45, 55, 66, 78, 91, 105, 120, 136, 153, 171, 190, 210]
# 実行時間:2.8755056858062744
# ==============================
# スレッド数16で処理しています...
# 20までの総和: [1, 3, 6, 10, 15, 21, 28, 36, 45, 55, 66, 78, 91, 105, 120, 136, 153, 171, 190, 210]
# 実行時間:2.4712677001953125
# ==============================
# スレッド数24で処理しています...
# 20までの総和: [1, 3, 6, 10, 15, 21, 28, 36, 45, 55, 66, 78, 91, 105, 120, 136, 153, 171, 190, 210]
# 実行時間:2.1091060638427734
# ==============================
# スレッド数36で処理しています...
# 20までの総和: [1, 3, 6, 10, 15, 21, 28, 36, 45, 55, 66, 78, 91, 105, 120, 136, 153, 171, 190, 210]
# 実行時間:2.0545742511749268
# ==============================
# スレッド数48で処理しています...
# 20までの総和: [1, 3, 6, 10, 15, 21, 28, 36, 45, 55, 66, 78, 91, 105, 120, 136, 153, 171, 190, 210]
# 実行時間:2.0600368976593018
# ==============================
# スレッド数96で処理しています...
# 20までの総和: [1, 3, 6, 10, 15, 21, 28, 36, 45, 55, 66, 78, 91, 105, 120, 136, 153, 171, 190, 210]
# 実行時間:2.0408260822296143
# ==============================

# %%
print("逐次処理")

start = time.time() ## 処理開始時間
##============計算処理==============
names = list(string.ascii_uppercase)
results = []
for name, number in zip(names, range(1, len(names) + 1)):
    time.sleep(0.5)
    results.append(f.studentID(name, number))
for i in results:
    print(i)
##=================================
end = time.time()  ## 処理終了時間
print(f"実行時間:{end - start}")
# Out:
# 逐次処理
# e195701 = Aさん
# e195702 = Bさん
# e195703 = Cさん
# e195704 = Dさん
# e195705 = Eさん
# e195706 = Fさん
# e195707 = Gさん
# e195708 = Hさん
# e195709 = Iさん
# e195710 = Jさん
# e195711 = Kさん
# e195712 = Lさん
# e195713 = Mさん
# e195714 = Nさん
# e195715 = Oさん
# e195716 = Pさん
# e195717 = Qさん
# e195718 = Rさん
# e195719 = Sさん
# e195720 = Tさん
# e195721 = Uさん
# e195722 = Vさん
# e195723 = Wさん
# e195724 = Xさん
# e195725 = Yさん
# e195726 = Zさん
# 実行時間:26.3737735748291

# %%
print("並列処理")

start = time.time() ## 処理開始時間
##============計算処理==============
names = list(string.ascii_uppercase)
results = []
with ThreadPoolExecutor(3) as e:
    for name, number in zip(names, range(1, len(names) + 1)):
        time.sleep(0.5)
        results.append(e.submit(f.studentID, name, number))
for i in results:
    print(i.result())
##=================================
end = time.time()  ## 処理終了時間
print(f"実行時間:{end - start}")
# Out:
# 並列処理
# e195701 = Aさん
# e195702 = Bさん
# e195703 = Cさん
# e195704 = Dさん
# e195705 = Eさん
# e195706 = Fさん
# e195707 = Gさん
# e195708 = Hさん
# e195709 = Iさん
# e195710 = Jさん
# e195711 = Kさん
# e195712 = Lさん
# e195713 = Mさん
# e195714 = Nさん
# e195715 = Oさん
# e195716 = Pさん
# e195717 = Qさん
# e195718 = Rさん
# e195719 = Sさん
# e195720 = Tさん
# e195721 = Uさん
# e195722 = Vさん
# e195723 = Wさん
# e195724 = Xさん
# e195725 = Yさん
# e195726 = Zさん
# 実行時間:13.613699913024902
